# %%
# 1. import package
import matplotlib.pyplot as plt

# %%
# 2. basic plot

plt.figure()
plt.plot([2,4,5,6,7,8,9,10,12,15])
plt.show()

# %%
# 2. basic plot - numpy

import numpy as np

t = np.arange(10,100,10)

plt.figure()
plt.plot(t)
plt.show()

# %%
# 3. curve  plot

x = np.arange(-3.14,3.14,0.1)
y = np.sin(x)

plt.figure()
plt.plot(x,y)
plt.show()

# %%
# 3. curve  plot - option

plt.figure(figsize = (10,8))

plt.plot(x,y)

plt.grid()
plt.xlabel('X')
plt.ylabel('Y')
plt.title("sin graph")

plt.show()


#https://matplotlib.org/users/pyplot_tutorial.html

# %%
# 3. curve  plot - double

y2 = np.cos(x)

plt.figure()

plt.plot(x,y)
plt.plot(x,y2)

plt.show()

# %%
# 3. curve  plot - label

plt.figure()

plt.plot(x,y,label = 'sin')
plt.plot(x,y2,label = 'cos')

plt.show()

# %%
# 3. curve  plot - appearance

plt.figure()

plt.plot(x,y,linestyle='--', color = 'red',linewidth=3.0)
plt.plot(x,y2,marker='*', color = 'blue',linewidth=0.5)

plt.show()

# %%
# 4. multi plot

a = np.arange(0,10,1)

plt.figure()

plt.plot(a,a,a,a**2,a,a**3)

plt.show()

# %%
# 4. multi plot - appearance

a = np.arange(0,10,1)

plt.figure()

plt.plot(a,a,'r:',a,a**2,'g+',a,a**3,'b--^')

plt.show()

# %%
# 4. multi plot - same sample

a = np.arange(0,10,1)

plt.figure()

plt.plot(a,a,'r:')
plt.plot(a,a**2,'g+')
plt.plot(a,a**3,'b--^')

plt.show()

# %%
# 5. scatter

x = np.arange(0,10,1)
y = np.array([1,6,14,5,7,17,3,2,9,5])

plt.figure()

plt.plot(x,y)

plt.show()

# %%
# 5. scatter

plt.figure()

plt.plot(x,y,'*')

plt.show()

# %%
# 5. scatter

plt.figure()

plt.scatter(x,y)

plt.show()

# %%
# 5. scatter - option
import random
plt.figure()
y = []
x = []

for i in range(100):
    y.append(random.randrange(1,100))
    x.append(random.randrange(1,100))
    
plt.scatter(x,y,c = np.arange(0,100,1),marker = 'o')
plt.colorbar()

plt.show()

# %%
# 5. bar

x = np.arange(0,10,1)
y = np.array([1,6,14,5,7,17,3,2,9,5])

plt.figure()

plt.bar(x,y)

plt.show()

# %%
# 5. bar

z = np.array([20,4,7,2,9,14,18,5,6,11])

plt.figure()

plt.bar(x,y)
plt.bar(x,z)

plt.show()

# %%
# 5. bar- two bar

z = np.array([20,4,7,2,9,14,18,5,6,11])

plt.figure()

plt.bar(x,y, width = 0.5)
plt.bar(x + 0.5,z,width = 0.5)

plt.show()

# %%
# 5. bar - apperance

plt.figure()

plt.bar(x,y, width = 0.3, label = 'y')
plt.bar(x + 0.4,z,width = 0.3, label = 'z')
plt.legend()

plt.xticks(x+0.2,('1th','2th','3th','4th','5th','6th','7th','8th','9th','10th',))

plt.show()

# %%
# 5. bar - barh

plt.figure()

plt.barh(x,y, label = 'y')
plt.barh(x,-z, label = 'z')
plt.legend()

plt.xticks([-20,-15,-10,-5,0,5,10,15,20],('20','15','10','5','0','5','10','15','20'))

plt.show()

# %%
# 5. pie

y = [20,40,60,80,100]

plt.figure()

plt.pie(y)

plt.show()

# %%
# 5. pie - apperence

label = ['blue','orange','green','red','purple']

plt.figure()

plt.pie(y,labels = label)

plt.show()

# %%
# 6. subplot

plt.figure()

plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,1,2)

plt.show()

# %%
# 6. subplot

plt.figure()

plt.subplot(221)
plt.subplot(222)
plt.subplot(212)

plt.show()

# %%
# 6. subplot
plt.close()
plt.figure()

plt.subplot(351)
plt.subplot(352)
plt.subplot(354)
plt.subplot(355)
plt.subplot(358)
plt.subplot(9,3,21)
plt.subplot(919)

plt.show()

# %%
# 6. subplot

plt.figure()

x = np.arange(0,10,1)
y = np.array([1,6,14,5,7,17,3,2,9,5])

plt.subplot(321)
plt.plot(x,y)
plt.grid()

plt.subplot(322)
plt.bar(x,y)
plt.grid()

plt.subplot(312)
plt.scatter(x,y)
plt.grid()

plt.subplot(325)
plt.plot(x,x**2)
plt.grid()

plt.subplot(326)
plt.pie(y)
plt.grid()

plt.show()

# %%
# -----------------------------------------------------------------------------
# Copyright (c) 2015, Nicolas P. Rougier. All Rights Reserved.
# Distributed under the (new) BSD License. See LICENSE.txt for more info.
# -----------------------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt

n = 8
X,Y = np.mgrid[0:n,0:n]
T = np.arctan2(Y-n/2.0, X-n/2.0)
R = 10+np.sqrt((Y-n/2.0)**2+(X-n/2.0)**2)
U,V = R*np.cos(T), R*np.sin(T)

plt.figure(figsize=(10,8))
plt.quiver(X,Y,U,V,R, alpha=.5)
plt.quiver(X,Y,U,V, edgecolor='k', facecolor='None', linewidth=.5)

plt.xlim(-1,n), plt.xticks([])
plt.ylim(-1,n), plt.yticks([])


plt.show()

# %%
# -----------------------------------------------------------------------------
# Copyright (c) 2015, Nicolas P. Rougier. All Rights Reserved.
# Distributed under the (new) BSD License. See LICENSE.txt for more info.
# -----------------------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.hot)
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.cm.hot)
ax.set_zlim(-2,2)


plt.show()

# %%
# -----------------------------------------------------------------------------
# Copyright (c) 2015, Nicolas P. Rougier. All Rights Reserved.
# Distributed under the (new) BSD License. See LICENSE.txt for more info.
# -----------------------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt

eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))

plt.figure(figsize=(10,10))

for i in range(24):
    index = np.random.randint(0,len(eqs))
    eq = eqs[index]
    size = np.random.uniform(12,32)
    x,y = np.random.uniform(0,1,2)
    alpha = np.random.uniform(0.25,.75)
    plt.text(x, y, eq, ha='center', va='center', color="#11557c", alpha=alpha,
             transform=plt.gca().transAxes, fontsize=size, clip_on=True)

plt.xticks([]), plt.yticks([])

plt.show()

# %%
"""
Illustrate simple contour plotting, contours on an image with
a colorbar for the contours, and labelled contours.

See also contour_image.py.
"""
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = mlab.bivariate_normal(X, Y, 1.0, 1.0, 0.0, 0.0)
Z2 = mlab.bivariate_normal(X, Y, 1.5, 0.5, 1, 1)
# difference of Gaussians
Z = 10.0 * (Z2 - Z1)


# Create a simple contour plot with labels using default colors.  The
# inline argument to clabel will control whether the labels are draw
# over the line segments of the contour, removing the lines beneath
# the label
plt.figure()
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
plt.title('Simplest default with labels')


# contour labels can be placed manually by providing list of positions
# (in data coordinate). See ginput_manual_clabel.py for interactive
# placement.
plt.figure()
CS = plt.contour(X, Y, Z)
manual_locations = [(-1, -1.4), (-0.62, -0.7), (-2, 0.5), (1.7, 1.2), (2.0, 1.4), (2.4, 1.7)]
plt.clabel(CS, inline=1, fontsize=10, manual=manual_locations)
plt.title('labels at selected locations')


# You can force all the contours to be the same color.
plt.figure()
CS = plt.contour(X, Y, Z, 6,
                 colors='k',  # negative contours will be dashed by default
                 )
plt.clabel(CS, fontsize=9, inline=1)
plt.title('Single color - negative contours dashed')

# You can set negative contours to be solid instead of dashed:
matplotlib.rcParams['contour.negative_linestyle'] = 'solid'
plt.figure()
CS = plt.contour(X, Y, Z, 6,
                 colors='k',  # negative contours will be dashed by default
                 )
plt.clabel(CS, fontsize=9, inline=1)
plt.title('Single color - negative contours solid')


# And you can manually specify the colors of the contour
plt.figure()
CS = plt.contour(X, Y, Z, 6,
                 linewidths=np.arange(.5, 4, .5),
                 colors=('r', 'green', 'blue', (1, 1, 0), '#afeeee', '0.5')
                 )
plt.clabel(CS, fontsize=9, inline=1)
plt.title('Crazy lines')


# Or you can use a colormap to specify the colors; the default
# colormap will be used for the contour lines
plt.figure()
im = plt.imshow(Z, interpolation='bilinear', origin='lower',
                cmap=cm.gray, extent=(-3, 3, -2, 2))
levels = np.arange(-1.2, 1.6, 0.2)
CS = plt.contour(Z, levels,
                 origin='lower',
                 linewidths=2,
                 extent=(-3, 3, -2, 2))

# Thicken the zero contour.
zc = CS.collections[6]
plt.setp(zc, linewidth=4)

plt.clabel(CS, levels[1::2],  # label every second level
           inline=1,
           fmt='%1.1f',
           fontsize=14)

# make a colorbar for the contour lines
CB = plt.colorbar(CS, shrink=0.8, extend='both')

plt.title('Lines with colorbar')
#plt.hot()  # Now change the colormap for the contour lines and colorbar
plt.flag()

# We can still add a colorbar for the image, too.
CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)

# This makes the original colorbar look a bit out of place,
# so let's improve its position.

l, b, w, h = plt.gca().get_position().bounds
ll, bb, ww, hh = CB.ax.get_position().bounds
CB.ax.set_position([ll, b + 0.1*h, ww, h*0.8])


plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# Load pandas
import pandas as pd

# Load numpy
import numpy as np
import csv

import time
from time import localtime, strftime
import datetime



# In[30]:

with open('./adult.data','r')as csvfile:
	reader = csv.reader(csvfile,delimiter = ',')
	train_target,train_result = [],[]
	for row in reader:
		if len(row) == 0:
			continue
		if row[13] == ' ?' or row[13] == ' Holand-Netherlands':
			continue

		train_target.append(row[:len(row)-1])
		train_result.append(row[len(row)-1])

	train_target = np.array(train_target)
	train_result = np.array(train_result)

	sample = np.random.choice(train_target.shape[0], 300, replace=False)
	train_target = train_target[sample]
	train_result = train_result[sample]

#print len(train_target)
print (len(train_result))



# In[36]:


with open('./adult.test','r')as csvfile:
	reader = csv.reader(csvfile,delimiter = ',')

	test_target,test_result = [],[]
	for row in reader:
		row = row[0].split(',')
		if len(row) == 0:
			continue
		if row[13] == ' ?' or row[13] == ' Holand-Netherlands':
			continue
		test_target.append(row[:len(row)-1])
        
		if row[14] == ' <=50K.':
			test_result.append(' <=50K')
		elif row[14] == ' >50K.':
			test_result.append(' >50K')
		else:
			print ("Unexpected Value")


	test_target = np.array(test_target)
	test_result = np.array(test_result)

print (train_target[0], train_result[0])	

print (np.count_nonzero(test_result == " <=50K"))

# In[37]:


# category transform

from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

for col in [1,3,5,6,7,8,9,13]:

	label_encoder = enc.fit(train_target[:,col])
	label_encoder_test = enc.fit(test_target[:,col])
	
	integer_classes = label_encoder.transform(label_encoder.classes_)
	integer_classes_test = label_encoder_test.transform(label_encoder_test.classes_)
	
	t = label_encoder.transform(train_target[:,col])
	s = label_encoder_test.transform(test_target[:,col])
	train_target[:,col] = t
	test_target[:,col] = s
	


label_encoder = enc.fit(train_result[:])
label_encoder_test = enc.fit(test_result[:])

integer_classes = label_encoder.transform(label_encoder.classes_)
integer_classes_test = label_encoder_test.transform(label_encoder_test.classes_)


t = label_encoder.transform(train_result[:])
s = label_encoder_test.transform(test_result[:])
train_result[:] = t
test_result[:] = s



from sklearn import metrics

def measure_performance(X,y,clf, show_accuracy=True, show_classification_report=True, show_confussion_matrix=True):

    y_pred=clf.predict(X)   

    if show_accuracy:
        print ("Accuracy:{0:.3f}".format(
            metrics.accuracy_score(y, y_pred)
        ),"\n")

    if show_classification_report:
        print ("Classification report")
        print (metrics.classification_report(y,y_pred),"\n")
      
    if show_confussion_matrix:
        print ("Confussion matrix")
        print (metrics.confusion_matrix(y,y_pred),"\n")




startTime = time.clock()

rf = RandomForestClassifier(n_estimators=100)
rf.fit(train_target, train_result)

endTime = time.clock()

measure_performance(test_target,test_result,rf)

print (endTime - startTime)
# Out:
# 300
# ['51' ' Self-emp-not-inc' ' 174824' ' HS-grad' ' 9' ' Never-married'
#  ' Farming-fishing' ' Not-in-family' ' White' ' Male' ' 8614' ' 0' ' 40'
#  ' United-States']  >50K
# 12235
# Accuracy:0.836
#
# Classification report
#              precision    recall  f1-score   support
#
#           0       0.86      0.94      0.90     12235
#           1       0.71      0.51      0.59      3772
#
# avg / total       0.83      0.84      0.83     16007
#
#
# Confussion matrix
# [[11468   767]
#  [ 1863  1909]]
#
# 0.16812124401351386

# %%
# In[49]:

import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, show

pred = rf.predict(test_target)

plt.close()
f, (ax1, ax2) = plt.subplots(1, 2)

labels = '<=50K', '>50K'
fracs = [np.count_nonzero(test_result == "0"),np.count_nonzero(test_result == "1")]
ax1.pie(fracs, labels = labels, autopct='%1.1f%%')
ax1.set_title('Test Set result value ratio', bbox={'facecolor': '0.8', 'pad': 5})

fracs = [np.count_nonzero(pred == "0"),np.count_nonzero(pred == "1")]
ax2.pie(fracs, labels = labels, autopct='%1.1f%%')
ax2.set_title('Predict Set result value ratio', bbox={'facecolor': '0.8', 'pad': 5})

print (f.set_size_inches([20,10]))

plt.show()
# Out:
# None
